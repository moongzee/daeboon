# %%
import pandas as pd

# %%
a=pd.read_csv("C:/Users/moonj/OneDrive/바탕 화면/자료.csv")
print(a)
# Out:
#       기간        합계  gdp  seoulforeigner
# 0   2012       NaN  2.4           204.0
# 1   2013       NaN  3.2           186.0
# 2   2014       NaN  3.2           202.0
# 3   2015  573378.0  2.8           227.0
# 4   2016  541673.0  2.9           226.0
# 5   2017  495792.0  3.2           174.2
# 6   2018  528063.0  2.9           187.4
# 7   2019  515051.0  2.0           166.0
# 8      0       0.0  0.0             0.0
# 9      0       0.0  0.0             0.0
# 10     0       0.0  0.0             0.0
# 11     0       0.0  0.0             0.0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(a.seoulforeigner, a.gdp)
plt.title("Scatter plot")
plt.xlabel('seoul foreigner')
plt.ylabel('gdp')
plt.show()

# %%
import seaborn as sns

# %%
cols=['seoulforeigner','gdp']
a2=a[cols]

sns.set(style='ticks')
sns.pairplot(a2)

# %%
import numpy as np

# %%
r=np.corrcoef(a.seoulforeigner,a.gdp)
print(r)
# Out:
# [[1.         0.96284496]
#  [0.96284496 1.        ]]
