# %% [markdown]
# # 3-point

# %% [markdown]
# ## **ver4.0의 문제점

# %%
from IPython.display import Image
Image(r'\\192.168.0.113\Imagoworks\AITeam\_Analysis\U-shape\ver5.0\ver4.0_err.png')

# %% [raw]
# 정규화에 따라 값에 차이가 있어서, 원인 분석 하는 중.

# %% [markdown]
# # ***개별 치아 무게중심 좌표 (x,y) 를 범위 (0,1)로 정규화한 후, 좌표의 분산을 조사

# %% [raw]
# 배경 : 개별 치아 무게중심 좌표의 분산이 작을수록, 개별 치아의 위치가 비슷한 곳에 있을 확률이 높음.
#        최대한 비슷한 위치에 분포한 치아로 세 점을 정하는 것이 어떨까 생각함.

# %% [markdown]
# ## 결과 : 분산값이 개별치아별로 작은값이 나와, 모든 치아가 비슷한 위치에 있다고 할 수 있음.

# %% [markdown]
# ## 특이사항 : mandible 의 전치 (1,9) 의 무게중심 좌표의 분산 값이 상대적으로 작음

# %% [raw]
# 생각외로 전치가 비슷한 위치에 있다고 할 수 있음.

# %%
Image(r'\\192.168.0.113\Imagoworks\AITeam\_Analysis\U-shape\ver5.0\var_merge.png')

# %% [markdown]
# ## mandible 개별치아 무게중심 x,y좌표에 대한 dist그래프

# %%
Image(r'\\192.168.0.113\Imagoworks\AITeam\_Analysis\U-shape\ver5.0\mn.png')

# %% [markdown]
# ## maxilla 개별치아 무게중심 x,y좌표에 대한 dist그래프

# %%
Image(r'\\192.168.0.113\Imagoworks\AITeam\_Analysis\U-shape\ver5.0\mx.png')
